# %%
import pandas as pd
import numpy as np

# %%
hosts_df = pd.read_csv('/Users/rafaelpeterson/Desktop/Bootcamp/Final Project/Data_Bootcamp_Final_Project/Source Files/olympic_hosts.csv')

# %%
medals_df = pd.read_csv('/Users/rafaelpeterson/Desktop/Bootcamp/Final Project/Data_Bootcamp_Final_Project/Source Files/olympic_medals.csv')

# %%
results_df = pd.read_csv('/Users/rafaelpeterson/Desktop/Bootcamp/Final Project/Data_Bootcamp_Final_Project/Source Files/olympic_results.csv')

# %%
athletes_df = pd.read_csv('/Users/rafaelpeterson/Desktop/Bootcamp/Final Project/archive (1)/olympic_athletes.csv')

# %%
athletes_df.head(5)
# Out:
#                                         athlete_url athlete_full_name  \
# 0      https://olympics.com/en/athletes/dongqi-chen       Dongqi CHEN
# 1  https://olympics.com/en/athletes/sagen-maddalena   Sagen MADDALENA
# 2  https://olympics.com/en/athletes/maria-martynova   Maria MARTYNOVA
# 3   https://olympics.com/en/athletes/yulia-karimova    Yulia KARIMOVA
# 4  https://olympics.com/en/athletes/najmeh-khedmati   Najmeh KHEDMATI
#
#    first_game  athlete_year_birth    athlete_medals  games_participations  bio
# 0  Tokyo 2020              1988.0               NaN                   NaN  NaN
# 1  Tokyo 2020              1993.0               NaN                   NaN  NaN
# 2  Tokyo 2020              1997.0               NaN                   NaN  NaN
# 3  Tokyo 2020              1994.0  \n\n\n2\n\nB\n\n                   1.0  NaN
# 4    Rio 2016              1996.0               NaN                   3.0  NaN

# %% [markdown]
# Clean athletes_df. Drop unnecessary columns, use dropna to get rid of NaN

# %%
athletes_df.drop(['athlete_url','bio', 'games_participations'], axis=1, inplace=True)
athletes_df.head()
# Out:
#   athlete_full_name  first_game  athlete_year_birth    athlete_medals
# 0       Dongqi CHEN  Tokyo 2020              1988.0               NaN
# 1   Sagen MADDALENA  Tokyo 2020              1993.0               NaN
# 2   Maria MARTYNOVA  Tokyo 2020              1997.0               NaN
# 3    Yulia KARIMOVA  Tokyo 2020              1994.0  \n\n\n2\n\nB\n\n
# 4   Najmeh KHEDMATI    Rio 2016              1996.0               NaN

# %%
athletes_df.dropna()
# Out:
#              athlete_full_name      first_game  athlete_year_birth  \
# 3               Yulia KARIMOVA      Tokyo 2020              1994.0
# 5                Nina CHRISTEN        Rio 2016              1994.0
# 25        Mary Carolynn TUCKER      Tokyo 2020              2001.0
# 29                  Eglys CRUZ     Athens 2004              1980.0
# 35             Snjezana PEJCIC    Beijing 2008              1982.0
# ...                        ...             ...                 ...
# 74682  Clarence Olivier GAMBLE  St. Louis 1904              1881.0
# 74683       Arthur Yancey WEAR  St. Louis 1904              1880.0
# 74695       Dimitrios LOUNDRAS     Athens 1896              1885.0
# 74705       Lyudmila PAKHOMOVA  Innsbruck 1976              1946.0
# 74706         Colleen O'CONNOR  Innsbruck 1976              1951.0
#
#                        athlete_medals
# 3                    \n\n\n2\n\nB\n\n
# 5      \n\n\n1\n\nG\n\n\n\n1\n\nB\n\n
# 25                   \n\n\n1\n\nS\n\n
# ...

# %% [markdown]
# Clean medals_df. Drop athlete_url, participant_title

# %%
medals_df.head(5)
# Out:
#   discipline_title   slug_game      event_title event_gender medal_type  \
# 0         Shooting  tokyo-2020  Trap Mixed Team        Mixed       GOLD
# 1         Shooting  tokyo-2020  Trap Mixed Team        Mixed       GOLD
# 2         Shooting  tokyo-2020  Trap Mixed Team        Mixed     SILVER
# 3         Shooting  tokyo-2020  Trap Mixed Team        Mixed     SILVER
# 4         Shooting  tokyo-2020  Trap Mixed Team        Mixed     BRONZE
#
#   participant_type         participant_title  \
# 0         GameTeam                     Spain
# 1         GameTeam                     Spain
# 2         GameTeam                San Marino
# 3         GameTeam                San Marino
# 4         GameTeam  United States of America
#
#                                          athlete_url    athlete_full_name  \
# 0     https://olympics.com/en/athletes/fatima-galvez        Fatima GALVEZ
# 1  https://olympics.com/en/athletes/alberto-ferna...    Alberto FERNANDEZ
# ...

# %%
medals_df.drop(['participant_title', 'athlete_url', 'athlete_full_name'], axis=1, inplace=True)

# %%
medals_df
# Out:
#       discipline_title    slug_game                      event_title  \
# 0             Shooting   tokyo-2020                  Trap Mixed Team
# 1             Shooting   tokyo-2020                  Trap Mixed Team
# 2             Shooting   tokyo-2020                  Trap Mixed Team
# 3             Shooting   tokyo-2020                  Trap Mixed Team
# 4             Shooting   tokyo-2020                  Trap Mixed Team
# ...                ...          ...                              ...
# 21305    Weightlifting  athens-1896  heavyweight - one hand lift men
# 21306    Weightlifting  athens-1896  heavyweight - one hand lift men
# 21307    Weightlifting  athens-1896  heavyweight - two hand lift men
# 21308    Weightlifting  athens-1896  heavyweight - two hand lift men
# 21309    Weightlifting  athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type              country_name  \
# ...

# %%
medals_df.dropna
# Out:
# <bound method DataFrame.dropna of       discipline_title    slug_game                      event_title  \
# 0             Shooting   tokyo-2020                  Trap Mixed Team
# 1             Shooting   tokyo-2020                  Trap Mixed Team
# 2             Shooting   tokyo-2020                  Trap Mixed Team
# 3             Shooting   tokyo-2020                  Trap Mixed Team
# 4             Shooting   tokyo-2020                  Trap Mixed Team
# ...                ...          ...                              ...
# 21305    Weightlifting  athens-1896  heavyweight - one hand lift men
# 21306    Weightlifting  athens-1896  heavyweight - one hand lift men
# 21307    Weightlifting  athens-1896  heavyweight - two hand lift men
# 21308    Weightlifting  athens-1896  heavyweight - two hand lift men
# 21309    Weightlifting  athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type              country_name  \
# ...

# %% [markdown]
# results: Drop 'athletes', 'athlete_url', 'athlete_full_name', 'value_unit', 'value_type', 'rank_equal'

# %%
results_df.head(5)
# Out:
#   discipline_title      event_title   slug_game participant_type medal_type  \
# 0         Shooting  Trap Mixed Team  tokyo-2020         GameTeam       GOLD
# 1         Shooting  Trap Mixed Team  tokyo-2020         GameTeam     SILVER
# 2         Shooting  Trap Mixed Team  tokyo-2020         GameTeam     BRONZE
# 3         Shooting  Trap Mixed Team  tokyo-2020         GameTeam        NaN
# 4         Shooting  Trap Mixed Team  tokyo-2020         GameTeam        NaN
#
#                                             athletes rank_equal rank_position  \
# 0  [('Fatima GALVEZ', 'https://olympics.com/en/at...      False             1
# 1  [('Alessandra PERILLI', 'https://olympics.com/...      False             2
# 2  [('Madelynn Ann BERNAU', 'https://olympics.com...      False             3
# 3  [('Zuzana STEFECEKOVA', 'https://olympics.com/...      False             4
# 4  [('Yukie NAKAYAMA', 'https://olympics.com/en/a...      False             5
#
# ...

# %%
results_df.drop(columns=['athletes', 'athlete_url', 'athlete_full_name', 'value_unit', 'value_type', 'rank_equal'], axis=1, inplace=True)

# %%
results_df.head()
# Out:
#   discipline_title      event_title   slug_game participant_type medal_type  \
# 0         Shooting  Trap Mixed Team  tokyo-2020         GameTeam       GOLD
# 1         Shooting  Trap Mixed Team  tokyo-2020         GameTeam     SILVER
# 2         Shooting  Trap Mixed Team  tokyo-2020         GameTeam     BRONZE
# 3         Shooting  Trap Mixed Team  tokyo-2020         GameTeam        NaN
# 4         Shooting  Trap Mixed Team  tokyo-2020         GameTeam        NaN
#
#   rank_position              country_name country_code country_3_letter_code
# 0             1                     Spain           ES                   ESP
# 1             2                San Marino           SM                   SMR
# 2             3  United States of America           US                   USA
# 3             4                  Slovakia           SK                   SVK
# 4             5                     Japan           JP                   JPN

# %%
hosts_df.head(5)
# Out:
#           game_slug         game_end_date       game_start_date  \
# 0        tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z
# 1  pyeongchang-2018  2018-02-25T08:00:00Z  2018-02-08T23:00:00Z
# 2          rio-2016  2016-08-21T21:00:00Z  2016-08-05T12:00:00Z
# 3        sochi-2014  2014-02-23T16:00:00Z  2014-02-07T04:00:00Z
# 4       london-2012  2012-08-12T19:00:00Z  2012-07-27T07:00:00Z
#
#         game_location         game_name game_season  game_year
# 0               Japan        Tokyo 2020      Summer       2020
# 1   Republic of Korea  PyeongChang 2018      Winter       2018
# 2              Brazil          Rio 2016      Summer       2016
# 3  Russian Federation        Sochi 2014      Winter       2014
# 4       Great Britain       London 2012      Summer       2012

# %%
from datetime import datetime as dt
hosts_df['game_end_date'] = pd.to_datetime(hosts_df['game_end_date']).dt.date
hosts_df['game_start_date'] = pd.to_datetime(hosts_df['game_start_date']).dt.date

# %%
hosts_df.head(5)
# Out:
#           game_slug game_end_date game_start_date       game_location  \
# 0        tokyo-2020    2021-08-08      2021-07-23               Japan
# 1  pyeongchang-2018    2018-02-25      2018-02-08   Republic of Korea
# 2          rio-2016    2016-08-21      2016-08-05              Brazil
# 3        sochi-2014    2014-02-23      2014-02-07  Russian Federation
# 4       london-2012    2012-08-12      2012-07-27       Great Britain
#
#           game_name game_season  game_year
# 0        Tokyo 2020      Summer       2020
# 1  PyeongChang 2018      Winter       2018
# 2          Rio 2016      Summer       2016
# 3        Sochi 2014      Winter       2014
# 4       London 2012      Summer       2012

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159020 entries, 0 to 159019
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   discipline_title       159020 non-null  object
#  1   event_title            159020 non-null  object
#  2   slug_game              159020 non-null  object
#  3   participant_type       159020 non-null  object
#  4   medal_type             19879 non-null   object
#  5   rank_position          155152 non-null  object
#  6   country_name           159020 non-null  object
#  7   country_code           153990 non-null  object
#  8   country_3_letter_code  159020 non-null  object
# dtypes: object(9)
# memory usage: 10.9+ MB

# %%
medals_df.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21310 entries, 0 to 21309
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   discipline_title       21310 non-null  object
#  1   slug_game              21310 non-null  object
#  2   event_title            21310 non-null  object
#  3   event_gender           21310 non-null  object
#  4   medal_type             21310 non-null  object
#  5   participant_type       21310 non-null  object
#  6   country_name           21310 non-null  object
#  7   country_code           19798 non-null  object
#  8   country_3_letter_code  21310 non-null  object
# dtypes: object(9)
# memory usage: 1.5+ MB

# %%
hosts_df.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   game_slug        52 non-null     object
#  1   game_end_date    52 non-null     object
#  2   game_start_date  52 non-null     object
#  3   game_location    52 non-null     object
#  4   game_name        52 non-null     object
#  5   game_season      52 non-null     object
#  6   game_year        52 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 3.0+ KB

# %% [markdown]
# rename DataFrames and convert to .csv

# %%
hosts_cleaned=hosts_df
hosts_cleaned.head()
# Out:
#           game_slug game_end_date game_start_date       game_location  \
# 0        tokyo-2020    2021-08-08      2021-07-23               Japan
# 1  pyeongchang-2018    2018-02-25      2018-02-08   Republic of Korea
# 2          rio-2016    2016-08-21      2016-08-05              Brazil
# 3        sochi-2014    2014-02-23      2014-02-07  Russian Federation
# 4       london-2012    2012-08-12      2012-07-27       Great Britain
#
#           game_name game_season  game_year
# 0        Tokyo 2020      Summer       2020
# 1  PyeongChang 2018      Winter       2018
# 2          Rio 2016      Summer       2016
# 3        Sochi 2014      Winter       2014
# 4       London 2012      Summer       2012

# %%
#hosts_cleaned.to_csv('hosts_cleaned.csv', index=False)

# %%
medals_cleaned=medals_df
medals_cleaned.head()
# Out:
#   discipline_title   slug_game      event_title event_gender medal_type  \
# 0         Shooting  tokyo-2020  Trap Mixed Team        Mixed       GOLD
# 1         Shooting  tokyo-2020  Trap Mixed Team        Mixed       GOLD
# 2         Shooting  tokyo-2020  Trap Mixed Team        Mixed     SILVER
# 3         Shooting  tokyo-2020  Trap Mixed Team        Mixed     SILVER
# 4         Shooting  tokyo-2020  Trap Mixed Team        Mixed     BRONZE
#
#   participant_type              country_name country_code  \
# 0         GameTeam                     Spain           ES
# 1         GameTeam                     Spain           ES
# 2         GameTeam                San Marino           SM
# 3         GameTeam                San Marino           SM
# 4         GameTeam  United States of America           US
#
#   country_3_letter_code
# 0                   ESP
# 1                   ESP
# 2                   SMR
# 3                   SMR
# 4                   USA

# %%
#medals_cleaned.to_csv('medals_cleaned.csv', index=False)

# %%
results_cleaned=results_df
results_cleaned.head()
# Out:
#   discipline_title      event_title   slug_game participant_type medal_type  \
# 0         Shooting  Trap Mixed Team  tokyo-2020         GameTeam       GOLD
# 1         Shooting  Trap Mixed Team  tokyo-2020         GameTeam     SILVER
# 2         Shooting  Trap Mixed Team  tokyo-2020         GameTeam     BRONZE
# 3         Shooting  Trap Mixed Team  tokyo-2020         GameTeam        NaN
# 4         Shooting  Trap Mixed Team  tokyo-2020         GameTeam        NaN
#
#   rank_position              country_name country_code country_3_letter_code
# 0             1                     Spain           ES                   ESP
# 1             2                San Marino           SM                   SMR
# 2             3  United States of America           US                   USA
# 3             4                  Slovakia           SK                   SVK
# 4             5                     Japan           JP                   JPN

# %%
#results_cleaned.to_csv('results_cleaned.csv', index=False)

# %%
athletes_cleaned=athletes_df
athletes_cleaned.head()
# Out:
#   athlete_full_name  first_game  athlete_year_birth    athlete_medals
# 0       Dongqi CHEN  Tokyo 2020              1988.0               NaN
# 1   Sagen MADDALENA  Tokyo 2020              1993.0               NaN
# 2   Maria MARTYNOVA  Tokyo 2020              1997.0               NaN
# 3    Yulia KARIMOVA  Tokyo 2020              1994.0  \n\n\n2\n\nB\n\n
# 4   Najmeh KHEDMATI    Rio 2016              1996.0               NaN

# %%
#athletes_cleaned.to_csv('athletes_cleaned.csv', index=False)

# %% [markdown]
# Code from 2/7 -

# %%
medals_cleaned.country_name.value_counts().head(20)
# Out:
# United States of America                3063
# Soviet Union                            1272
# Germany                                 1131
# Great Britain                           1041
# France                                   932
# People's Republic of China               790
# Italy                                    785
# Sweden                                   689
# Australia                                623
# Russian Federation                       599
# Canada                                   574
# Japan                                    569
# German Democratic Republic (Germany)     562
# Hungary                                  555
# Norway                                   550
# Netherlands                              483
# Finland                                  481
# Switzerland                              387
# Republic of Korea                        383
# Austria                                  352
# Name: country_name, dtype: int64

# %%
medals_cleaned.country_name.value_counts()
# Out:
# United States of America    3063
# Soviet Union                1272
# Germany                     1131
# Great Britain               1041
# France                       932
#                             ...
# Cyprus                         1
# Paraguay                       1
# Eritrea                        1
# Togo                           1
# Gabon                          1
# Name: country_name, Length: 154, dtype: int64

# %%
# code from https://www.kaggle.com/kalilurrahman/olympic-games-eda to adjust historical country names to their modern names.

medals_cleaned["country_code"].replace({"URS": "RUS",
                             "ROC": "RUS",
                             "OAR": "RUS",
                             "ORS": "RUS",
                             "GDR": "GER",
                             "FRG": "GER"}, inplace=True)
medals_cleaned["country_name"].replace({"Russian Federation": "Russia",
                        "Soviet Union": "Russia",
                        "Unified team": "Russia",
                        "West Germany": "Germany",
                        "East Germany": "Germany",
                        "German Democratic Republic (Germany)": "Germany"}, inplace=True)

# %%
medals_cleaned.slug_game.describe()
# Out:
# count          21310
# unique            52
# top       tokyo-2020
# freq            1168
# Name: slug_game, dtype: object

# %%
location = hosts_cleaned['game_location']
location.head()
# Out:
# 0                 Japan
# 1     Republic of Korea
# 2                Brazil
# 3    Russian Federation
# 4         Great Britain
# Name: game_location, dtype: object

# %%
#Merge olympics_hosts and olympics_medals. Code based off eda from https://www.kaggle.com/kalilurrahman/olympic-games-eda

olympics_results = pd.merge(hosts_cleaned, medals_cleaned,
                           left_on=  ['game_slug'],
                           right_on= ['slug_game'],
                           how = 'left')
olympics_results.head(10)
# Out:
#     game_slug game_end_date game_start_date game_location   game_name  \
# 0  tokyo-2020    2021-08-08      2021-07-23         Japan  Tokyo 2020
# 1  tokyo-2020    2021-08-08      2021-07-23         Japan  Tokyo 2020
# 2  tokyo-2020    2021-08-08      2021-07-23         Japan  Tokyo 2020
# 3  tokyo-2020    2021-08-08      2021-07-23         Japan  Tokyo 2020
# 4  tokyo-2020    2021-08-08      2021-07-23         Japan  Tokyo 2020
# 5  tokyo-2020    2021-08-08      2021-07-23         Japan  Tokyo 2020
# 6  tokyo-2020    2021-08-08      2021-07-23         Japan  Tokyo 2020
# 7  tokyo-2020    2021-08-08      2021-07-23         Japan  Tokyo 2020
# 8  tokyo-2020    2021-08-08      2021-07-23         Japan  Tokyo 2020
# 9  tokyo-2020    2021-08-08      2021-07-23         Japan  Tokyo 2020
#
#   game_season  game_year discipline_title   slug_game  \
# 0      Summer       2020         Shooting  tokyo-2020
# 1      Summer       2020         Shooting  tokyo-2020
# ...

# %%
olympics_results.columns
# Out:
# Index(['game_slug', 'game_end_date', 'game_start_date', 'game_location',
#        'game_name', 'game_season', 'game_year', 'discipline_title',
#        'slug_game', 'event_title', 'event_gender', 'medal_type',
#        'participant_type', 'country_name', 'country_code',
#        'country_3_letter_code'],
#       dtype='object')

# %%
olympics_results.value_counts(['medal_type'])
# Out:
# medal_type
# BRONZE        7401
# GOLD          6978
# SILVER        6931
# dtype: int64

# %%
clean_olympics_results= olympics_results.drop(['game_end_date', 'game_start_date', 'game_name', 'game_season', 'game_year', 'discipline_title', 'game_slug', 'event_title', 'event_gender', 'medal_type', 'participant_type', 'country_3_letter_code', 'slug_game', 'country_code'], 1)
# Out:
# /Users/rafaelpeterson/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
clean_olympics_results.dropna()
# Out:
#       game_location              country_name
# 0             Japan                     Spain
# 1             Japan                     Spain
# 2             Japan                San Marino
# 3             Japan                San Marino
# 4             Japan  United States of America
# ...             ...                       ...
# 21305        Greece                   Denmark
# 21306        Greece                    Greece
# 21307        Greece                   Denmark
# 21308        Greece             Great Britain
# 21309        Greece                    Greece
#
# [21310 rows x 2 columns]

# %%
# adding column of home field winners
clean_olympics_results['home_winner'] = np.where(clean_olympics_results['game_location'] == clean_olympics_results['country_name'], True, False)
clean_olympics_results.head()
# Out:
#   game_location              country_name  home_winner
# 0         Japan                     Spain        False
# 1         Japan                     Spain        False
# 2         Japan                San Marino        False
# 3         Japan                San Marino        False
# 4         Japan  United States of America        False

# %%
clean_olympics_results.to_csv('clean_olympic_results.csv', index=False)

# %%
#making new df with rows where game_location & country_name match

matching = clean_olympics_results[clean_olympics_results['game_location'] == clean_olympics_results['country_name']]
matching
# Out:
#       game_location country_name  home_winner
# 192           Japan        Japan         True
# 196           Japan        Japan         True
# 199           Japan        Japan         True
# 242           Japan        Japan         True
# 245           Japan        Japan         True
# ...             ...          ...          ...
# 21298        Greece       Greece         True
# 21302        Greece       Greece         True
# 21303        Greece       Greece         True
# 21306        Greece       Greece         True
# 21309        Greece       Greece         True
#
# [1243 rows x 3 columns]

# %%
clean_olympics_results["game_location"].replace({"Russian Federation": "Russia",
                        "Soviet Union": "Russia",
                        "Unified team": "Russia",
                        "West Germany": "Germany",
                        "East Germany": "Germany",
                        "German Democratic Republic (Germany)": "Germany",
                        "Federal Republic of Germany": "Germany",
                        "Australia, Sweden" : "Australia"}, inplace=True)

# %%
# adding column of home field winners
clean_olympics_results['home_winner'] = np.where(clean_olympics_results['game_location'] == clean_olympics_results['country_name'], True, False)
clean_olympics_results.head()
# Out:
#   game_location              country_name  home_winner
# 0         Japan                     Spain        False
# 1         Japan                     Spain        False
# 2         Japan                San Marino        False
# 3         Japan                San Marino        False
# 4         Japan  United States of America        False

# %%
# Converting true/false into 1, 0 https://stackoverflow.com/questions/17383094/how-can-i-map-true-false-to-1-0-in-a-pandas-dataframe
clean_olympics_results["home_winner"] = clean_olympics_results["home_winner"].astype(bool).astype(int)

# %%
clean_olympics_results['home_winner'].value_counts()
# Out:
# 0    19967
# 1     1343
# Name: home_winner, dtype: int64

# %%
country_counts.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
clean2 = pd.get_dummies(clean_olympics_results, drop_first=True)

clean2.head()
# Out:
#    home_winner  game_location_Austria  game_location_Belgium  \
# 0            0                      0                      0
# 1            0                      0                      0
# 2            0                      0                      0
# 3            0                      0                      0
# 4            0                      0                      0
#
#    game_location_Brazil  game_location_Canada  game_location_China  \
# 0                     0                     0                    0
# 1                     0                     0                    0
# 2                     0                     0                    0
# 3                     0                     0                    0
# 4                     0                     0                    0
#
#    game_location_Finland  game_location_France  game_location_Germany  \
# 0                      0                     0                      0
# ...

# %%
# # Scaling
# from sklearn.preprocessing import StandardScaler
# scaler= StandardScaler()

# # fit input data
# scaler.fit(df_2)

# # Scale data
# scaled_data = scaler.transform(df_2)

# # Create a DataFrame with the scaled data
# transformed_scaled_data = pd.DataFrame(scaled_data, columns=df_2.columns)
# transformed_scaled_data.head()

# %%
# Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import tensorflow as tf



# Split our preprocessed data into our features and target arrays
y = clean2["home_winner"].values
X = clean2.drop(["home_winner"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# /Users/rafaelpeterson/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# trying random forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Create a random forest classifier.
rf_model = RandomForestClassifier(n_estimators=20, random_state=78)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# Making predictions using the testing data.
predictions = rf_model.predict(X_test_scaled)

# Calculating the confusion matrix.
cm = confusion_matrix(y_test, predictions)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0         5008            0
# Actual 1           47          273

# %%
# Calculating the accuracy score.
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0         5008            0
# Actual 1           47          273
# Accuracy Score : 0.9911786786786787
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5008
#            1       1.00      0.85      0.92       320
#
#     accuracy                           0.99      5328
#    macro avg       1.00      0.93      0.96      5328
# weighted avg       0.99      0.99      0.99      5328
